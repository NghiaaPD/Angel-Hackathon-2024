# %%
# !nvidia-smi
# Out:
# Thu Mar 21 14:28:27 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.86                 Driver Version: 551.86         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   55C    P5             14W /  105W |     325MiB /   6144MiB |     49%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
from ultralytics import YOLO

model = YOLO('./model/best.pt')

results = model('./video/pexels_videos_2053100 (2160p).mp4', show=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
# video 1/1 (frame 1/1800) D:\codeN\Python\Python Homework\CPV\Project2-CPV\video\pexels_videos_2053100 (2160p).mp4: 384x640 14 cars, 2 trucks, 245.7ms
# video 1/1 (frame 2/1800) D:\codeN\Python\Python Homework\CPV\Project2-CPV\video\pexels_videos_2053100 (2160p).mp4: 384x640 1 person, 14 cars, 2 trucks, 322.9ms
# ...
